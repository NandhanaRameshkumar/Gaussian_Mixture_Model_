# %% [markdown]
# <a href="https://colab.research.google.com/github/NandhanaRameshkumar/Gaussian_Mixture_Model_/blob/main/Gaussian_Mixture_Model_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.mixture import GaussianMixture
from sklearn.decomposition import PCA

# Load data from CSV file into a pandas DataFrame
data = pd.read_csv('head.csv')

# Extract features (assuming your features are in columns 0 to n-1)
X = data.iloc[:, :-1].values

# Instantiate GMM
gmm = GaussianMixture(n_components=3, random_state=42)

# Fit GMM to data
gmm.fit(X)

# Predict clusters
labels = gmm.predict(X)

# Reduce dimensionality for visualization (using PCA)
pca = PCA(n_components=2)
X_reduced = pca.fit_transform(X)

# Visualize clusters
plt.figure(figsize=(10, 6))

colors = ['red', 'green', 'blue']
for i in range(3):
    plt.scatter(X_reduced[labels == i, 0], X_reduced[labels == i, 1], c=colors[i], label=f'Cluster {i+1}')

plt.title('Gaussian Mixture Model Clustering')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.legend()
plt.grid(True)
plt.show()
